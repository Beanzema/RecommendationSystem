# %%
import numpy as np
import pandas as pd
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime, timedelta
import math

# %%
# UTC_time 변경 함수

def date_convert(date_to_convert):
    pru = datetime.datetime.strptime(date_to_convert, '%a %b %d %H:%M:%S +0000 %Y')+ datetime.timedelta(hours=-240//60)
    return pru.strftime('%b %d %Y %H:%M:%S')

def tzo_convert(tzo_to_convert):
    return  timedelta(hours=tzo_to_convert/60)

# %%
nyc_filepath = 'C:/Users/piai/Desktop/code_file/dataset_WWW2019/dataset_TSMC2014_NYC.csv\dataset_TSMC2014_NYC.csv'
custom_date_parser = lambda x: datetime.strptime(x, "%a %b %d %H:%M:%S +0000 %Y")

nyc_data = pd.read_csv(nyc_filepath,parse_dates=['utcTimestamp'],date_parser=custom_date_parser)

nyc_data["utcTimestampOffset"] = nyc_data.utcTimestamp + nyc_data.timezoneOffset.apply(tzo_convert)

nyc_data["hour"] = nyc_data.utcTimestampOffset.dt.hour

# 야행성인지 체크하는 컬럼 생성. 저녁 6시부터 새벽 6시까지 활동한 POI는 야행성 Ture로 표시.
nyc_data["nightlife"] = nyc_data['hour'].apply(lambda x: 'True' if (18 <= x < 24) or (0 <= x < 6)else 'False')

# 요일이 무엇인지 0~6 순서로 설정. 월요일이 0, 일요일이 6.
nyc_data["dayofweek"] = nyc_data.utcTimestampOffset.dt.dayofweek

# 평일과 주말을 구분. 평일이면 True, 주말이면 False.
nyc_data["weekday"] = nyc_data['dayofweek'].apply(lambda x: 'True' if x <= 4 else 'False')

# %%
nyc_data
# Out:
#         userId                   venueId           venueCategoryId  \
# 0          470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1          979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2           69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3          395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4           87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# ...        ...                       ...                       ...
# 227423     688  3fd66200f964a52000e71ee3  4bf58dd8d48988d1e7931735
# 227424     560  4bca32ff0687ef3be789dbcc  4bf58dd8d48988d16c941735
# 227425     945  50a77716e4b0b5a9492f6f56  4bf58dd8d48988d103941735
# 227426     671  4514efe0f964a520e7391fe3  4bf58dd8d48988d11d941735
# 227427     942  4a1e0ca0f964a520bf7b1fe3  4bf58dd8d48988d116941735
#
#               venueCategory   latitude  longitude  timezoneOffset  \
# 0       Arts & Crafts Store  40.719810 -74.002581            -240
# 1                    Bridge  40.606800 -74.044170            -240
# 2            Home (private)  40.716162 -73.883070            -240
# 3            Medical Center  40.745164 -73.982519            -240
# 4                Food Truck  40.740104 -73.989658            -240
# ...                     ...        ...        ...             ...
# 227423          Music Venue  40.733596 -74.003139            -300
# 227424         Burger Joint  40.745719 -73.993720            -300
# 227425       Home (private)  40.854365 -73.883070            -300
# 227426                  Bar  40.735981 -74.029309            -300
# 227427                  Bar  40.726805 -73.957422            -300
#
#               utcTimestamp  utcTimestampOffset  hour nightlife  dayofweek  \
# 0      2012-04-03 18:00:09 2012-04-03 14:00:09    14     False          1
# 1      2012-04-03 18:00:25 2012-04-03 14:00:25    14     False          1
# 2      2012-04-03 18:02:24 2012-04-03 14:02:24    14     False          1
# 3      2012-04-03 18:02:41 2012-04-03 14:02:41    14     False          1
# 4      2012-04-03 18:03:00 2012-04-03 14:03:00    14     False          1
# ...                    ...                 ...   ...       ...        ...
# 227423 2013-02-16 02:29:11 2013-02-15 21:29:11    21      True          4
# 227424 2013-02-16 02:31:35 2013-02-15 21:31:35    21      True          4
# 227425 2013-02-16 02:33:16 2013-02-15 21:33:16    21      True          4
# 227426 2013-02-16 02:34:31 2013-02-15 21:34:31    21      True          4
# 227427 2013-02-16 02:35:36 2013-02-15 21:35:36    21      True          4
#
#        weekday
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# ...        ...
# 227423    True
# 227424    True
# 227425    True
# 227426    True
# 227427    True
#
# [227428 rows x 13 columns]

# %%
# 유저 아이디 별로 정렬 후
# 유저 아이디 행 수만큼만 len 돌려서 time delta 하고,
# 이대로 컬럼 하나 추가하기.
nyc_data_sorted = nyc_data.sort_values(by=['userId', 'utcTimestampOffset'], ascending=[True, True])
nyc_data_sorted.reset_index(inplace= True, drop= True)

# %%
nyc_data_sorted['time_diff'] = (nyc_data_sorted.utcTimestampOffset.shift(-1) - nyc_data_sorted.utcTimestampOffset)

# %%
nyc_data_sorted['duplicate'] = False
nyc_data_sorted['timedelta_min'] = nyc_data_sorted['time_diff']/timedelta(minutes=1)

# %%
for i in range(1, len(nyc_data_sorted) -1):
    if i == len(nyc_data_sorted) - 1:
        continue
    if nyc_data_sorted.loc[i, "userId"] == nyc_data_sorted.loc[i-1, "userId"]:
        if ((nyc_data_sorted.loc[i, 'venueCategory'] == nyc_data_sorted.loc[i-1, 'venueCategory']) & (nyc_data_sorted.loc[i, 'timedelta_min'] < 60)) | (nyc_data_sorted.loc[i-1, 'timedelta_min'] < 3):
            # 같은 아이디 내에서 카테고리가 연달아 중복되는데, POI 인증 시간차가 60min 미만인 경우 or 다음 POI까지 인증이 3min 미만인 경우(POI는 다르게 중복 인증하는 실수를 한 경우)는 중복이라고 체크.
            nyc_data_sorted.loc[i, 'duplicate'] = True
    if (i > 0) & (nyc_data_sorted.loc[i, "userId"] != nyc_data_sorted.loc[i-1, "userId"]):
        nyc_data_sorted.loc[i-1, 'time_diff'] = pd.to_timedelta(0, unit='h')

# %%
# 중복 제거
condition = nyc_data_sorted[nyc_data_sorted['duplicate'] == True].index
nyc_data_sorted.drop(condition, inplace= True)

# %%
# POI 인증별 시간차 다시 update
nyc_data_sorted['time_diff'] = (nyc_data_sorted.utcTimestampOffset.shift(-1) - nyc_data_sorted.utcTimestampOffset)
nyc_data_sorted['timedelta_min'] = nyc_data_sorted['time_diff']/timedelta(minutes=1)
nyc_data_sorted.reset_index(inplace= True, drop= True)

# %%
poi_list = pd.read_csv('C:/Users/piai/Desktop/code_file/category_list_for_categorize_for_lstm_update.txt', header = None)
poi_list.columns = ['venueCategory','Category']
poi_list.head()
# Out:
#        venueCategory  Category
# 0        Post Office     Other
# 1          Jazz Club    Liquid
# 2                Gym  Exercise
# 3  Indian Restaurant      Meal
# 4     Sandwich Place      Meal

# %% [markdown]
# ## 인증 텀을 120min까지로 늘리고, Category에서 Transportation, Work, School를 제외하자.

# %%
nyc_data_sorted = pd.merge(nyc_data_sorted,poi_list, how='left', left_on='venueCategory', right_on='venueCategory')

# %%
tmp_df = nyc_data_sorted[(nyc_data_sorted['timedelta_min'] < 120) & (nyc_data_sorted['Category'] != 'Transportation') & (nyc_data_sorted['Category'] != 'Work') & (nyc_data_sorted['Category'] != 'School')]
tmp_df2 = nyc_data_sorted.loc[[(i + 1) for i in list(tmp_df.index)]]
tmp_df3 = pd.concat([tmp_df, tmp_df2])

tmp_df3 = tmp_df3.sort_values(['userId', 'utcTimestampOffset'])
tmp_df3.drop_duplicates(inplace=True)

# tmp_df3를 가지고 세션 데이터를 생성해보자.
tmp_df3['SessionId'] = None

# %%
tmp_df3['Category'].value_counts()
# Out:
# Meal              12777
# Shopping           9102
# Other              6905
# Liquid             5592
# Residence          5422
# Entertain          3684
# Leisure            3665
# Work               3606
# Transportation     2996
# Cafe               2829
# Snack              2335
# Exercise           1982
# Sightseeing        1749
# Retail             1373
# School             1106
# Resort              930
# Event               561
# Hobby               556
# Name: Category, dtype: int64

# %%
tmp_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68314 entries, 2 to 192125
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   userId              68314 non-null  int64
#  1   venueId             68314 non-null  object
#  2   venueCategoryId     68314 non-null  object
#  3   venueCategory       68314 non-null  object
#  4   latitude            68314 non-null  float64
#  5   longitude           68314 non-null  float64
#  6   timezoneOffset      68314 non-null  int64
#  7   utcTimestamp        68314 non-null  datetime64[ns]
#  8   utcTimestampOffset  68314 non-null  datetime64[ns]
#  9   hour                68314 non-null  int64
#  10  nightlife           68314 non-null  object
#  11  dayofweek           68314 non-null  int64
#  12  weekday             68314 non-null  object
#  13  time_diff           68314 non-null  timedelta64[ns]
#  14  duplicate           68314 non-null  bool
#  15  timedelta_min       68314 non-null  float64
#  16  Category            67170 non-null  object
#  17  SessionId           0 non-null      object
# dtypes: bool(1), datetime64[ns](2), float64(3), int64(4), object(7), timedelta64[ns](1)
# memory usage: 9.4+ MB

# %%
tmp_df3.reset_index(inplace= True, drop= True)

# %%
index = 0
SessionId = 0
last = nyc_data_sorted.loc[len(nyc_data_sorted)-1, 'userId']
for i in range(len(tmp_df3)):
    tmp_df3.loc[i, 'SessionId'] = SessionId
    if tmp_df3.loc[i, 'timedelta_min'] >= 120:
        SessionId += 1

# %%
tmp_df3
# Out:
#        userId                   venueId           venueCategoryId  \
# 0           1  4db44994cda1c57c82583709  4bf58dd8d48988d1f1931735
# 1           1  4a541923f964a52008b31fe3  4bf58dd8d48988d14e941735
# 2           1  46ea2358f964a520cf4a1fe3  4bf58dd8d48988d11d941735
# 3           1  4d081fb700e6b1f7d4060cd7  4bf58dd8d48988d113941735
# 4           1  40fb0f00f964a520d90a1fe3  4bf58dd8d48988d11b941735
# ...       ...                       ...                       ...
# 68309    1083  49edce76f964a520f9671fe3  4bf58dd8d48988d124941735
# 68310    1083  4b102c19f964a5208f6a23e3  4bf58dd8d48988d103951735
# 68311    1083  4eda64ced5fb8f213a5d740e  4bf58dd8d48988d176941735
# 68312    1083  49f4dca6f964a520626b1fe3  4bf58dd8d48988d1c1941735
# 68313    1083  40b68100f964a52085001fe3  4bf58dd8d48988d116941735
#
#                venueCategory   latitude  longitude  timezoneOffset  \
# 0      General Entertainment  40.739398 -73.993210            -240
# 1        American Restaurant  40.785677 -73.976498            -240
# 2                        Bar  40.760667 -73.994948            -240
# 3          Korean Restaurant  40.764104 -73.986725            -240
# 4                        Bar  40.760645 -73.986065            -240
# ...                      ...        ...        ...             ...
# 68309                 Office  40.755764 -73.985812            -300
# 68310         Clothing Store  40.749347 -73.986782            -300
# 68311   Gym / Fitness Center  40.746119 -73.993070            -300
# 68312     Mexican Restaurant  40.735174 -73.979597            -300
# 68313                    Bar  40.737831 -73.981022            -300
#
#              utcTimestamp  utcTimestampOffset  hour nightlife  dayofweek  \
# 0     2012-04-08 18:20:29 2012-04-08 14:20:29    14     False          6
# 1     2012-04-08 20:02:10 2012-04-08 16:02:10    16     False          6
# 2     2012-04-14 01:11:20 2012-04-13 21:11:20    21      True          4
# 3     2012-04-14 03:07:56 2012-04-13 23:07:56    23      True          4
# 4     2012-04-14 04:45:13 2012-04-14 00:45:13     0      True          5
# ...                   ...                 ...   ...       ...        ...
# 68309 2013-01-04 17:58:37 2013-01-04 12:58:37    12     False          4
# 68310 2013-01-08 00:32:35 2013-01-07 19:32:35    19      True          0
# 68311 2013-01-08 01:12:17 2013-01-07 20:12:17    20      True          0
# 68312 2013-02-02 04:19:34 2013-02-01 23:19:34    23      True          4
# 68313 2013-02-02 04:48:36 2013-02-01 23:48:36    23      True          4
#
#       weekday       time_diff  duplicate  timedelta_min   Category SessionId
# 0       False 0 days 01:41:41      False     101.683333  Entertain         0
# 1       False 0 days 20:18:42      False    1218.700000       Meal         0
# 2        True 0 days 01:56:36      False     116.600000     Liquid         1
# 3        True 0 days 01:37:17      False      97.283333       Meal         1
# 4       False 0 days 11:12:07      False     672.116667     Liquid         1
# ...       ...             ...        ...            ...        ...       ...
# 68309    True 0 days 04:16:32      False     256.533333       Work     24958
# 68310    True 0 days 00:39:42      False      39.700000   Shopping     24959
# 68311    True 0 days 14:14:11      False     854.183333   Exercise     24959
# 68312    True 0 days 00:29:02      False      29.033333       Meal     24960
# 68313    True 5 days 18:49:19      False    8329.316667     Liquid     24960
#
# [68314 rows x 18 columns]

# %%
import datetime as dt
from pathlib import Path
import os

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
tmp_df3.loc[tmp_df3['venueCategory'].str.contains('Caf'), 'Category'] = 'Cafe'
tmp_df3.loc[tmp_df3['venueCategory'].str.contains('Gas Station'), 'Category'] = 'Other'
tmp_df3[tmp_df3['Category'].isnull()]
# Out:
# Empty DataFrame
# Columns: [userId, venueId, venueCategoryId, venueCategory, latitude, longitude, timezoneOffset, utcTimestamp, utcTimestampOffset, hour, nightlife, dayofweek, weekday, time_diff, duplicate, timedelta_min, Category, SessionId]
# Index: []

# %%
tmp_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68314 entries, 0 to 68313
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   userId              68314 non-null  int64
#  1   venueId             68314 non-null  object
#  2   venueCategoryId     68314 non-null  object
#  3   venueCategory       68314 non-null  object
#  4   latitude            68314 non-null  float64
#  5   longitude           68314 non-null  float64
#  6   timezoneOffset      68314 non-null  int64
#  7   utcTimestamp        68314 non-null  datetime64[ns]
#  8   utcTimestampOffset  68314 non-null  datetime64[ns]
#  9   hour                68314 non-null  int64
#  10  nightlife           68314 non-null  object
#  11  dayofweek           68314 non-null  int64
#  12  weekday             68314 non-null  object
#  13  time_diff           68314 non-null  timedelta64[ns]
#  14  duplicate           68314 non-null  bool
#  15  timedelta_min       68314 non-null  float64
#  16  Category            68314 non-null  object
#  17  SessionId           68314 non-null  object
# dtypes: bool(1), datetime64[ns](2), float64(3), int64(4), object(7), timedelta64[ns](1)
# memory usage: 8.9+ MB

# %%
id2idx = {item_id : index for index, item_id in enumerate(tmp_df3['Category'].unique())}

# %%
def indexing(df, id2idx):
    df['item_idx'] = df['ItemId'].map(lambda x: id2idx.get(x, -1))
    # id2idx에 없는 아이템은 모르는 값(-1) 처리.
    return df

# %%
# short_session을 제거한 다음 unpopular item을 제거하면 다시 길이가 1인 session이 생길 수 있다.
# 이를 위해 반복문을 통해 지속적으로 제거한다.
def cleanse_recursive(data: pd.DataFrame, shortest, least_click) -> pd.DataFrame:
    while True:
        before_len = len(data)
        data = cleanse_short_session(data, shortest)
        data = cleanse_unpopular_item(data, least_click)
        after_len = len(data)
        if before_len == after_len:
            break
    return data


def cleanse_short_session(data: pd.DataFrame, shortest):
    session_len = data.groupby('SessionId').size()
    session_use = session_len[session_len >= shortest].index
    data = data[data['SessionId'].isin(session_use)]
    return data


def cleanse_unpopular_item(data: pd.DataFrame, least_click):
    item_popular = data.groupby('Category').size()
    item_use = item_popular[item_popular >= least_click].index
    data = data[data['Category'].isin(item_use)]
    return data

# %%
data = cleanse_recursive(tmp_df3, shortest=3, least_click=1)
data.head(10)
# Out:
#     userId                   venueId           venueCategoryId  \
# 2        1  46ea2358f964a520cf4a1fe3  4bf58dd8d48988d11d941735
# 3        1  4d081fb700e6b1f7d4060cd7  4bf58dd8d48988d113941735
# 4        1  40fb0f00f964a520d90a1fe3  4bf58dd8d48988d11b941735
# 7        1  4b8afdb0f964a520038d32e3  4bf58dd8d48988d1d5941735
# 8        1  4afca7e0f964a520d02422e3  4bf58dd8d48988d1d1941735
# 9        1  4e742aabc65bb91db3cadb79  4bf58dd8d48988d116941735
# 10       1  3fd66200f964a520fbe71ee3  4bf58dd8d48988d16c941735
# 11       1  4e691e82b9930387355c629d  4bf58dd8d48988d14e941735
# 12       1  3fd66200f964a520f0e51ee3  4bf58dd8d48988d10d951735
# 13       1  49dc03d9f964a520445f1fe3  4bf58dd8d48988d116941735
#
#             venueCategory   latitude  longitude  timezoneOffset  \
# 2                     Bar  40.760667 -73.994948            -240
# 3       Korean Restaurant  40.764104 -73.986725            -240
# 4                     Bar  40.760645 -73.986065            -240
# 7                   Hotel  40.756247 -73.972692            -240
# 8   Ramen /  Noodle House  40.757197 -73.968780            -240
# 9                     Bar  40.757305 -73.968640            -240
# 10           Burger Joint  40.758819 -73.968657            -240
# 11    American Restaurant  40.725163 -73.992160            -240
# 12            Record Shop  40.728912 -73.999300            -240
# 13                    Bar  40.729658 -73.998515            -240
#
#           utcTimestamp  utcTimestampOffset  hour nightlife  dayofweek weekday  \
# 2  2012-04-14 01:11:20 2012-04-13 21:11:20    21      True          4    True
# 3  2012-04-14 03:07:56 2012-04-13 23:07:56    23      True          4    True
# 4  2012-04-14 04:45:13 2012-04-14 00:45:13     0      True          5   False
# 7  2012-04-14 20:03:42 2012-04-14 16:03:42    16     False          5   False
# 8  2012-04-14 21:24:08 2012-04-14 17:24:08    17     False          5   False
# 9  2012-04-14 22:07:43 2012-04-14 18:07:43    18      True          5   False
# 10 2012-04-14 23:15:07 2012-04-14 19:15:07    19      True          5   False
# 11 2012-04-21 16:28:11 2012-04-21 12:28:11    12     False          5   False
# 12 2012-04-21 18:22:21 2012-04-21 14:22:21    14     False          5   False
# 13 2012-04-21 18:48:58 2012-04-21 14:48:58    14     False          5   False
#
#          time_diff  duplicate  timedelta_min Category SessionId
# 2  0 days 01:56:36      False     116.600000   Liquid         1
# 3  0 days 01:37:17      False      97.283333     Meal         1
# 4  0 days 11:12:07      False     672.116667   Liquid         1
# 7  0 days 01:20:26      False      80.433333   Resort         3
# 8  0 days 00:43:35      False      43.583333     Meal         3
# 9  0 days 01:07:24      False      67.400000   Liquid         3
# 10 1 days 16:38:53      False    2438.883333     Meal         3
# 11 0 days 01:54:10      False     114.166667     Meal         4
# 12 0 days 00:26:37      False      26.616667    Hobby         4
# 13 0 days 00:29:51      False      29.850000   Liquid         4

# %%
data
# Out:
#        userId                   venueId           venueCategoryId  \
# 2           1  46ea2358f964a520cf4a1fe3  4bf58dd8d48988d11d941735
# 3           1  4d081fb700e6b1f7d4060cd7  4bf58dd8d48988d113941735
# 4           1  40fb0f00f964a520d90a1fe3  4bf58dd8d48988d11b941735
# 7           1  4b8afdb0f964a520038d32e3  4bf58dd8d48988d1d5941735
# 8           1  4afca7e0f964a520d02422e3  4bf58dd8d48988d1d1941735
# ...       ...                       ...                       ...
# 68297    1083  460d4b66f964a52005451fe3  4bf58dd8d48988d118951735
# 68298    1083  4a53d9a7f964a520c7b21fe3  4bf58dd8d48988d124941735
# 68301    1083  4ade3c4df964a5202a7421e3  4bf58dd8d48988d10c951735
# 68302    1083  4a7dcf5cf964a520b5ef1fe3  4bf58dd8d48988d1f8941735
# 68303    1083  4ba53a1ff964a5209aee38e3  4bf58dd8d48988d104951735
#
#                 venueCategory   latitude  longitude  timezoneOffset  \
# 2                         Bar  40.760667 -73.994948            -240
# 3           Korean Restaurant  40.764104 -73.986725            -240
# 4                         Bar  40.760645 -73.986065            -240
# 7                       Hotel  40.756247 -73.972692            -240
# 8       Ramen /  Noodle House  40.757197 -73.968780            -240
# ...                       ...        ...        ...             ...
# 68297       Food & Drink Shop  40.744818 -73.995152            -240
# 68298                  Office  40.745518 -73.992351            -240
# 68301          Cosmetics Shop  40.739084 -73.991384            -240
# 68302  Furniture / Home Store  40.740019 -73.994696            -240
# 68303          Clothing Store  40.740693 -73.997097            -240
#
#              utcTimestamp  utcTimestampOffset  hour nightlife  dayofweek  \
# 2     2012-04-14 01:11:20 2012-04-13 21:11:20    21      True          4
# 3     2012-04-14 03:07:56 2012-04-13 23:07:56    23      True          4
# 4     2012-04-14 04:45:13 2012-04-14 00:45:13     0      True          5
# 7     2012-04-14 20:03:42 2012-04-14 16:03:42    16     False          5
# 8     2012-04-14 21:24:08 2012-04-14 17:24:08    17     False          5
# ...                   ...                 ...   ...       ...        ...
# 68297 2012-07-16 16:41:15 2012-07-16 12:41:15    12     False          0
# 68298 2012-07-16 18:39:06 2012-07-16 14:39:06    14     False          0
# 68301 2012-09-09 20:01:48 2012-09-09 16:01:48    16     False          6
# 68302 2012-09-09 20:58:57 2012-09-09 16:58:57    16     False          6
# 68303 2012-09-09 22:10:27 2012-09-09 18:10:27    18      True          6
#
#       weekday       time_diff  duplicate  timedelta_min  Category SessionId
# 2        True 0 days 01:56:36      False     116.600000    Liquid         1
# 3        True 0 days 01:37:17      False      97.283333      Meal         1
# 4       False 0 days 11:12:07      False     672.116667    Liquid         1
# 7       False 0 days 01:20:26      False      80.433333    Resort         3
# 8       False 0 days 00:43:35      False      43.583333      Meal         3
# ...       ...             ...        ...            ...       ...       ...
# 68297    True 0 days 01:57:51      False     117.850000      Meal     24953
# 68298    True 0 days 03:53:46      False     233.766667      Work     24953
# 68301   False 0 days 00:57:09      False      57.150000  Shopping     24955
# 68302   False 0 days 01:11:30      False      71.500000  Shopping     24955
# 68303   False 3 days 16:10:38      False    5290.633333  Shopping     24955
#
# [34404 rows x 18 columns]

# %%
id2idx = {item_id : index for index, item_id in enumerate(data['Category'].unique())}

# %%
def indexing(df, id2idx):
    df['item_idx'] = df['Category'].map(lambda x: id2idx.get(x, -1))
    # id2idx에 없는 아이템은 모르는 값(-1) 처리.
    return df

# %%
total_dataset = indexing(data, id2idx)
total_dataset
# Out:
#        userId                   venueId           venueCategoryId  \
# 2           1  46ea2358f964a520cf4a1fe3  4bf58dd8d48988d11d941735
# 3           1  4d081fb700e6b1f7d4060cd7  4bf58dd8d48988d113941735
# 4           1  40fb0f00f964a520d90a1fe3  4bf58dd8d48988d11b941735
# 7           1  4b8afdb0f964a520038d32e3  4bf58dd8d48988d1d5941735
# 8           1  4afca7e0f964a520d02422e3  4bf58dd8d48988d1d1941735
# ...       ...                       ...                       ...
# 68297    1083  460d4b66f964a52005451fe3  4bf58dd8d48988d118951735
# 68298    1083  4a53d9a7f964a520c7b21fe3  4bf58dd8d48988d124941735
# 68301    1083  4ade3c4df964a5202a7421e3  4bf58dd8d48988d10c951735
# 68302    1083  4a7dcf5cf964a520b5ef1fe3  4bf58dd8d48988d1f8941735
# 68303    1083  4ba53a1ff964a5209aee38e3  4bf58dd8d48988d104951735
#
#                 venueCategory   latitude  longitude  timezoneOffset  \
# 2                         Bar  40.760667 -73.994948            -240
# 3           Korean Restaurant  40.764104 -73.986725            -240
# 4                         Bar  40.760645 -73.986065            -240
# 7                       Hotel  40.756247 -73.972692            -240
# 8       Ramen /  Noodle House  40.757197 -73.968780            -240
# ...                       ...        ...        ...             ...
# 68297       Food & Drink Shop  40.744818 -73.995152            -240
# 68298                  Office  40.745518 -73.992351            -240
# 68301          Cosmetics Shop  40.739084 -73.991384            -240
# 68302  Furniture / Home Store  40.740019 -73.994696            -240
# 68303          Clothing Store  40.740693 -73.997097            -240
#
#              utcTimestamp  utcTimestampOffset  hour nightlife  dayofweek  \
# 2     2012-04-14 01:11:20 2012-04-13 21:11:20    21      True          4
# 3     2012-04-14 03:07:56 2012-04-13 23:07:56    23      True          4
# 4     2012-04-14 04:45:13 2012-04-14 00:45:13     0      True          5
# 7     2012-04-14 20:03:42 2012-04-14 16:03:42    16     False          5
# 8     2012-04-14 21:24:08 2012-04-14 17:24:08    17     False          5
# ...                   ...                 ...   ...       ...        ...
# 68297 2012-07-16 16:41:15 2012-07-16 12:41:15    12     False          0
# 68298 2012-07-16 18:39:06 2012-07-16 14:39:06    14     False          0
# 68301 2012-09-09 20:01:48 2012-09-09 16:01:48    16     False          6
# 68302 2012-09-09 20:58:57 2012-09-09 16:58:57    16     False          6
# 68303 2012-09-09 22:10:27 2012-09-09 18:10:27    18      True          6
#
#       weekday       time_diff  duplicate  timedelta_min  Category SessionId  \
# 2        True 0 days 01:56:36      False     116.600000    Liquid         1
# 3        True 0 days 01:37:17      False      97.283333      Meal         1
# 4       False 0 days 11:12:07      False     672.116667    Liquid         1
# 7       False 0 days 01:20:26      False      80.433333    Resort         3
# 8       False 0 days 00:43:35      False      43.583333      Meal         3
# ...       ...             ...        ...            ...       ...       ...
# 68297    True 0 days 01:57:51      False     117.850000      Meal     24953
# 68298    True 0 days 03:53:46      False     233.766667      Work     24953
# 68301   False 0 days 00:57:09      False      57.150000  Shopping     24955
# 68302   False 0 days 01:11:30      False      71.500000  Shopping     24955
# 68303   False 3 days 16:10:38      False    5290.633333  Shopping     24955
#
#        item_idx
# 2             0
# 3             1
# 4             0
# 7             2
# 8             1
# ...         ...
# 68297         1
# 68298        10
# 68301         4
# 68302         4
# 68303         4
#
# [34404 rows x 19 columns]

# %%
tmp_total = total_dataset[:]

# %%
tmp_total
# Out:
#        userId                   venueId           venueCategoryId  \
# 2           1  46ea2358f964a520cf4a1fe3  4bf58dd8d48988d11d941735
# 3           1  4d081fb700e6b1f7d4060cd7  4bf58dd8d48988d113941735
# 4           1  40fb0f00f964a520d90a1fe3  4bf58dd8d48988d11b941735
# 7           1  4b8afdb0f964a520038d32e3  4bf58dd8d48988d1d5941735
# 8           1  4afca7e0f964a520d02422e3  4bf58dd8d48988d1d1941735
# ...       ...                       ...                       ...
# 68297    1083  460d4b66f964a52005451fe3  4bf58dd8d48988d118951735
# 68298    1083  4a53d9a7f964a520c7b21fe3  4bf58dd8d48988d124941735
# 68301    1083  4ade3c4df964a5202a7421e3  4bf58dd8d48988d10c951735
# 68302    1083  4a7dcf5cf964a520b5ef1fe3  4bf58dd8d48988d1f8941735
# 68303    1083  4ba53a1ff964a5209aee38e3  4bf58dd8d48988d104951735
#
#                 venueCategory   latitude  longitude  timezoneOffset  \
# 2                         Bar  40.760667 -73.994948            -240
# 3           Korean Restaurant  40.764104 -73.986725            -240
# 4                         Bar  40.760645 -73.986065            -240
# 7                       Hotel  40.756247 -73.972692            -240
# 8       Ramen /  Noodle House  40.757197 -73.968780            -240
# ...                       ...        ...        ...             ...
# 68297       Food & Drink Shop  40.744818 -73.995152            -240
# 68298                  Office  40.745518 -73.992351            -240
# 68301          Cosmetics Shop  40.739084 -73.991384            -240
# 68302  Furniture / Home Store  40.740019 -73.994696            -240
# 68303          Clothing Store  40.740693 -73.997097            -240
#
#              utcTimestamp  utcTimestampOffset  hour nightlife  dayofweek  \
# 2     2012-04-14 01:11:20 2012-04-13 21:11:20    21      True          4
# 3     2012-04-14 03:07:56 2012-04-13 23:07:56    23      True          4
# 4     2012-04-14 04:45:13 2012-04-14 00:45:13     0      True          5
# 7     2012-04-14 20:03:42 2012-04-14 16:03:42    16     False          5
# 8     2012-04-14 21:24:08 2012-04-14 17:24:08    17     False          5
# ...                   ...                 ...   ...       ...        ...
# 68297 2012-07-16 16:41:15 2012-07-16 12:41:15    12     False          0
# 68298 2012-07-16 18:39:06 2012-07-16 14:39:06    14     False          0
# 68301 2012-09-09 20:01:48 2012-09-09 16:01:48    16     False          6
# 68302 2012-09-09 20:58:57 2012-09-09 16:58:57    16     False          6
# 68303 2012-09-09 22:10:27 2012-09-09 18:10:27    18      True          6
#
#       weekday       time_diff  duplicate  timedelta_min  Category SessionId  \
# 2        True 0 days 01:56:36      False     116.600000    Liquid         1
# 3        True 0 days 01:37:17      False      97.283333      Meal         1
# 4       False 0 days 11:12:07      False     672.116667    Liquid         1
# 7       False 0 days 01:20:26      False      80.433333    Resort         3
# 8       False 0 days 00:43:35      False      43.583333      Meal         3
# ...       ...             ...        ...            ...       ...       ...
# 68297    True 0 days 01:57:51      False     117.850000      Meal     24953
# 68298    True 0 days 03:53:46      False     233.766667      Work     24953
# 68301   False 0 days 00:57:09      False      57.150000  Shopping     24955
# 68302   False 0 days 01:11:30      False      71.500000  Shopping     24955
# 68303   False 3 days 16:10:38      False    5290.633333  Shopping     24955
#
#        item_idx
# 2             0
# 3             1
# 4             0
# 7             2
# 8             1
# ...         ...
# 68297         1
# 68298        10
# 68301         4
# 68302         4
# 68303         4
#
# [34404 rows x 19 columns]

# %%
# 데이터가 주어지면 세션이 시작되는 인덱스를 담는 값과 세션을 새로 인덱싱한 값을 갖는 클래스를 만든다.
class SessionDataset:
    
    def __init__(self, data):
        self.df = data
        self.click_offsets = self.get_click_offsets()     # 각 세션이 시작된 인덱스를 가진 변수
        self.session_idx = np.arange(self.df['SessionId'].nunique())  # indexing to SessionId
    
    def get_click_offsets(self):
        """
        Return the indexes of the first click of each session IDs,
        """
        offsets = np.zeros(self.df['SessionId'].nunique() + 1, dtype=np.int32)
        offsets[1:] = self.df.groupby('SessionId').size().cumsum()
        return offsets

# %%
tmp_total = SessionDataset(tmp_total).df

# %%
tmp_total
# Out:
#        userId                   venueId           venueCategoryId  \
# 2           1  46ea2358f964a520cf4a1fe3  4bf58dd8d48988d11d941735
# 3           1  4d081fb700e6b1f7d4060cd7  4bf58dd8d48988d113941735
# 4           1  40fb0f00f964a520d90a1fe3  4bf58dd8d48988d11b941735
# 7           1  4b8afdb0f964a520038d32e3  4bf58dd8d48988d1d5941735
# 8           1  4afca7e0f964a520d02422e3  4bf58dd8d48988d1d1941735
# ...       ...                       ...                       ...
# 68297    1083  460d4b66f964a52005451fe3  4bf58dd8d48988d118951735
# 68298    1083  4a53d9a7f964a520c7b21fe3  4bf58dd8d48988d124941735
# 68301    1083  4ade3c4df964a5202a7421e3  4bf58dd8d48988d10c951735
# 68302    1083  4a7dcf5cf964a520b5ef1fe3  4bf58dd8d48988d1f8941735
# 68303    1083  4ba53a1ff964a5209aee38e3  4bf58dd8d48988d104951735
#
#                 venueCategory   latitude  longitude  timezoneOffset  \
# 2                         Bar  40.760667 -73.994948            -240
# 3           Korean Restaurant  40.764104 -73.986725            -240
# 4                         Bar  40.760645 -73.986065            -240
# 7                       Hotel  40.756247 -73.972692            -240
# 8       Ramen /  Noodle House  40.757197 -73.968780            -240
# ...                       ...        ...        ...             ...
# 68297       Food & Drink Shop  40.744818 -73.995152            -240
# 68298                  Office  40.745518 -73.992351            -240
# 68301          Cosmetics Shop  40.739084 -73.991384            -240
# 68302  Furniture / Home Store  40.740019 -73.994696            -240
# 68303          Clothing Store  40.740693 -73.997097            -240
#
#              utcTimestamp  utcTimestampOffset  hour nightlife  dayofweek  \
# 2     2012-04-14 01:11:20 2012-04-13 21:11:20    21      True          4
# 3     2012-04-14 03:07:56 2012-04-13 23:07:56    23      True          4
# 4     2012-04-14 04:45:13 2012-04-14 00:45:13     0      True          5
# 7     2012-04-14 20:03:42 2012-04-14 16:03:42    16     False          5
# 8     2012-04-14 21:24:08 2012-04-14 17:24:08    17     False          5
# ...                   ...                 ...   ...       ...        ...
# 68297 2012-07-16 16:41:15 2012-07-16 12:41:15    12     False          0
# 68298 2012-07-16 18:39:06 2012-07-16 14:39:06    14     False          0
# 68301 2012-09-09 20:01:48 2012-09-09 16:01:48    16     False          6
# 68302 2012-09-09 20:58:57 2012-09-09 16:58:57    16     False          6
# 68303 2012-09-09 22:10:27 2012-09-09 18:10:27    18      True          6
#
#       weekday       time_diff  duplicate  timedelta_min  Category SessionId  \
# 2        True 0 days 01:56:36      False     116.600000    Liquid         1
# 3        True 0 days 01:37:17      False      97.283333      Meal         1
# 4       False 0 days 11:12:07      False     672.116667    Liquid         1
# 7       False 0 days 01:20:26      False      80.433333    Resort         3
# 8       False 0 days 00:43:35      False      43.583333      Meal         3
# ...       ...             ...        ...            ...       ...       ...
# 68297    True 0 days 01:57:51      False     117.850000      Meal     24953
# 68298    True 0 days 03:53:46      False     233.766667      Work     24953
# 68301   False 0 days 00:57:09      False      57.150000  Shopping     24955
# 68302   False 0 days 01:11:30      False      71.500000  Shopping     24955
# 68303   False 3 days 16:10:38      False    5290.633333  Shopping     24955
#
#        item_idx
# 2             0
# 3             1
# 4             0
# 7             2
# 8             1
# ...         ...
# 68297         1
# 68298        10
# 68301         4
# 68302         4
# 68303         4
#
# [34404 rows x 19 columns]

# %%
tmp_total
# Out:
#        userId                   venueId           venueCategoryId  \
# 2           1  46ea2358f964a520cf4a1fe3  4bf58dd8d48988d11d941735
# 3           1  4d081fb700e6b1f7d4060cd7  4bf58dd8d48988d113941735
# 4           1  40fb0f00f964a520d90a1fe3  4bf58dd8d48988d11b941735
# 7           1  4b8afdb0f964a520038d32e3  4bf58dd8d48988d1d5941735
# 8           1  4afca7e0f964a520d02422e3  4bf58dd8d48988d1d1941735
# ...       ...                       ...                       ...
# 68297    1083  460d4b66f964a52005451fe3  4bf58dd8d48988d118951735
# 68298    1083  4a53d9a7f964a520c7b21fe3  4bf58dd8d48988d124941735
# 68301    1083  4ade3c4df964a5202a7421e3  4bf58dd8d48988d10c951735
# 68302    1083  4a7dcf5cf964a520b5ef1fe3  4bf58dd8d48988d1f8941735
# 68303    1083  4ba53a1ff964a5209aee38e3  4bf58dd8d48988d104951735
#
#                 venueCategory   latitude  longitude  timezoneOffset  \
# 2                         Bar  40.760667 -73.994948            -240
# 3           Korean Restaurant  40.764104 -73.986725            -240
# 4                         Bar  40.760645 -73.986065            -240
# 7                       Hotel  40.756247 -73.972692            -240
# 8       Ramen /  Noodle House  40.757197 -73.968780            -240
# ...                       ...        ...        ...             ...
# 68297       Food & Drink Shop  40.744818 -73.995152            -240
# 68298                  Office  40.745518 -73.992351            -240
# 68301          Cosmetics Shop  40.739084 -73.991384            -240
# 68302  Furniture / Home Store  40.740019 -73.994696            -240
# 68303          Clothing Store  40.740693 -73.997097            -240
#
#              utcTimestamp  utcTimestampOffset  hour nightlife  dayofweek  \
# 2     2012-04-14 01:11:20 2012-04-13 21:11:20    21      True          4
# 3     2012-04-14 03:07:56 2012-04-13 23:07:56    23      True          4
# 4     2012-04-14 04:45:13 2012-04-14 00:45:13     0      True          5
# 7     2012-04-14 20:03:42 2012-04-14 16:03:42    16     False          5
# 8     2012-04-14 21:24:08 2012-04-14 17:24:08    17     False          5
# ...                   ...                 ...   ...       ...        ...
# 68297 2012-07-16 16:41:15 2012-07-16 12:41:15    12     False          0
# 68298 2012-07-16 18:39:06 2012-07-16 14:39:06    14     False          0
# 68301 2012-09-09 20:01:48 2012-09-09 16:01:48    16     False          6
# 68302 2012-09-09 20:58:57 2012-09-09 16:58:57    16     False          6
# 68303 2012-09-09 22:10:27 2012-09-09 18:10:27    18      True          6
#
#       weekday       time_diff  duplicate  timedelta_min  Category SessionId  \
# 2        True 0 days 01:56:36      False     116.600000    Liquid         1
# 3        True 0 days 01:37:17      False      97.283333      Meal         1
# 4       False 0 days 11:12:07      False     672.116667    Liquid         1
# 7       False 0 days 01:20:26      False      80.433333    Resort         3
# 8       False 0 days 00:43:35      False      43.583333      Meal         3
# ...       ...             ...        ...            ...       ...       ...
# 68297    True 0 days 01:57:51      False     117.850000      Meal     24953
# 68298    True 0 days 03:53:46      False     233.766667      Work     24953
# 68301   False 0 days 00:57:09      False      57.150000  Shopping     24955
# 68302   False 0 days 01:11:30      False      71.500000  Shopping     24955
# 68303   False 3 days 16:10:38      False    5290.633333  Shopping     24955
#
#        item_idx
# 2             0
# 3             1
# 4             0
# 7             2
# 8             1
# ...         ...
# 68297         1
# 68298        10
# 68301         4
# 68302         4
# 68303         4
#
# [34404 rows x 19 columns]

# %%
# arr = np.empty((0,3), int)

# for i in list(tmp_total['SessionId'].drop_duplicates()):
#     tmp = tmp_total[tmp_total['SessionId'] == i]
#     if len(tmp) >= 3:
#         # print('input')
#         input = tmp.iloc[:2]['item_idx']
#         # print(tmp.iloc[:2]['item_idx'])
#         # print('output')
#         output = tmp[2:3]['item_idx']
#         # print(tmp[2:3]['item_idx'])
#         in_and_out = tmp[:3]['item_idx']
#         array = np.array(in_and_out)
#         arr = np.append(arr, [np.array(in_and_out)], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\piai\Desktop\code_file\GRU추천모델_데이터셋고도화.ipynb Cell 37' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/piai/Desktop/code_file/GRU%EC%B6%94%EC%B2%9C%EB%AA%A8%EB%8D%B8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B%EA%B3%A0%EB%8F%84%ED%99%94.ipynb#ch0000032?line=0'>1</a> arr = np.empty((0,3), int)
#       <a href='vscode-notebook-cell:/c%3A/Users/piai/Desktop/code_file/GRU%EC%B6%94%EC%B2%9C%EB%AA%A8%EB%8D%B8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B%EA%B3%A0%EB%8F%84%ED%99%94.ipynb#ch0000032?line=2'>3</a> for i in list(tmp_total['SessionId'].drop_duplicates()):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/piai/Desktop/code_file/GRU%EC%B6%94%EC%B2%9C%EB%AA%A8%EB%8D%B8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B%EA%B3%A0%EB%8F%84%ED%99%94.ipynb#ch0000032?line=3'>4</a>     tmp = tmp_total[tmp_total['SessionId'] == i]
#       <a href='vscode-notebook-cell:/c%3A/Users/piai/Desktop/code_file/GRU%EC%B6%94%EC%B2%9C%EB%AA%A8%EB%8D%B8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B%EA%B3%A0%EB%8F%84%ED%99%94.ipynb#ch0000032?line=4'>5</a>     if len(tmp) >= 3:
#       <a href='vscode-notebook-cell:/c%3A/Users/piai/Desktop/code_file/GRU%EC%B6%94%EC%B2%9C%EB%AA%A8%EB%8D%B8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B%EA%B3%A0%EB%8F%84%ED%99%94.ipynb#ch0000032?line=5'>6</a>         # print('input')
#       <a href='vscode-notebook-cell:/c%3A/Users/piai/Desktop/code_file/GRU%EC%B6%94%EC%B2%9C%EB%AA%A8%EB%8D%B8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B%EA%B3%A0%EB%8F%84%ED%99%94.ipynb#ch0000032?line=6'>7</a>         input = tmp.iloc[:2]['item_idx']
#
# File c:\Users\piai\anaconda3\lib\site-packages\pandas\core\frame.py:3496, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3493'>3494</a> # Do we have a (boolean) 1d indexer?
#    <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3494'>3495</a> if com.is_bool_indexer(key):
# -> <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3495'>3496</a>     return self._getitem_bool_array(key)
#    <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3497'>3498</a> # We are left with two options: a single key, and a collection of keys,
#    <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3498'>3499</a> # We interpret tuples as collections only for non-MultiIndex
#    <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3499'>3500</a> is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\Users\piai\anaconda3\lib\site-packages\pandas\core\frame.py:3550, in DataFrame._getitem_bool_array(self, key)
#    <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3546'>3547</a> # check_bool_indexer will throw exception if Series key cannot
#    <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3547'>3548</a> # be reindexed to match DataFrame rows
#    <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3548'>3549</a> key = check_bool_indexer(self.index, key)
# -> <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3549'>3550</a> indexer = key.nonzero()[0]
#    <a href='file:///c%3A/Users/piai/anaconda3/lib/site-packages/pandas/core/frame.py?line=3550'>3551</a> return self._take_with_is_copy(indexer, axis=0)
#
# KeyboardInterrupt:

# %%
arr = np.empty((0,3), int)

for i in list(tmp_total['SessionId'].drop_duplicates()):
    tmp = tmp_total[tmp_total['SessionId'] == i]
    if len(tmp) >= 3:
        for j in range(len(tmp)):
            try:
                in_and_out = tmp[j:j+3]['item_idx']
                arr = np.append(arr, [np.array(in_and_out)], axis=0)
            except:
                continue

# %%
len(arr)
# Out:
# 18392

# %%
id2idx
# Out:
# {'Liquid': 0,
#  'Meal': 1,
#  'Resort': 2,
#  'Hobby': 3,
#  'Shopping': 4,
#  'Retail': 5,
#  'Snack': 6,
#  'Cafe': 7,
#  'Transportation': 8,
#  'Sightseeing': 9,
#  'Work': 10,
#  'Leisure': 11,
#  'Residence': 12,
#  'Entertain': 13,
#  'Other': 14,
#  'Event': 15,
#  'Exercise': 16,
#  'School': 17}

# %%
pd.Series(arr[:,-1][int(len(arr)*0.7):]).drop_duplicates().sort_values()
# Out:
# 0       0
# 8       1
# 336     2
# 19      3
# 1       4
# 94      5
# 2       6
# 40      7
# 14      8
# 18      9
# 4      10
# 49     11
# 10     12
# 41     13
# 70     14
# 5      15
# 39     16
# 133    17
# dtype: int64

# %%
print(arr[:,:-1])
print(arr[:,-1])
# input과 output으로 잘 쪼개졌다.
# Out:
# [[ 0  1]
#  [ 2  1]
#  [ 1  0]
#  ...
#  [16  8]
#  [ 8  1]
#  [ 4  4]]
# [ 0  0  1 ...  1 10  4]

# %%
print('X shape : ', arr[:,:-1].shape)
print('Y shape : ', arr[:,-1].shape)
# Out:
# X shape :  (18392, 2)
# Y shape :  (18392,)

# %%
# split
data_train = arr[:int(len(arr)*0.7)]
data_val = arr[int(len(arr)*0.7):int(len(arr)*0.9)]
data_test = arr[int(len(arr)*0.9):]

# %%
x_train = data_train[:,:-1]
y_train = data_train[:,-1]

x_val = data_val[:,:-1]
y_val = data_val[:,-1]

x_test = data_test[:,:-1]
y_test = data_test[:,-1]

# %%
x_train
# Out:
# array([[ 0,  1],
#        [ 2,  1],
#        [ 1,  0],
#        ...,
#        [10, 11],
#        [ 0,  0],
#        [ 4,  1]], dtype=int64)

# %%
import matplotlib.pyplot as pltfrom
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, GRU, Dropout
from keras.preprocessing import sequence
from keras.utils import np_utils

import numpy
import tensorflow as tf
import matplotlib.pyplot as plt

y_train = np_utils.to_categorical(y_train)
y_val = np_utils.to_categorical(y_val)
y_test = np_utils.to_categorical(y_test)

# %%
regression_GRU = Sequential()

regression_GRU.add(Embedding(1000,100))
regression_GRU.add(GRU(units=100, activation="relu", return_sequences=True, input_shape = (x_train.shape[1], 5)))
regression_GRU.add(Dropout(0.2))

regression_GRU.add(GRU(units=60, activation="relu", return_sequences=True))
regression_GRU.add(Dropout(0.3))

regression_GRU.add(GRU(units=80, activation="relu", return_sequences=True))
regression_GRU.add(Dropout(0.4))

regression_GRU.add(GRU(units=120, activation="relu"))
regression_GRU.add(Dropout(0.5))

regression_GRU.add(Dense(units = 18,activation='softmax'))

# %%
model = Sequential()
model.add(Embedding(1000,100))
model.add(GRU(100, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(18, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy','top_k_categorical_accuracy'])

# %%
y_train.shape
# Out:
# (12874, 18)

# %%
history = model.fit(x_train, y_train, batch_size=100, epochs=20, validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 129/129 [==============================] - 3s 10ms/step - loss: 2.6697 - accuracy: 0.1605 - top_k_categorical_accuracy: 0.5598 - val_loss: 2.5345 - val_accuracy: 0.1759 - val_top_k_categorical_accuracy: 0.6098
# Epoch 2/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.5459 - accuracy: 0.1857 - top_k_categorical_accuracy: 0.6084 - val_loss: 2.5101 - val_accuracy: 0.1960 - val_top_k_categorical_accuracy: 0.6213
# Epoch 3/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.5164 - accuracy: 0.1954 - top_k_categorical_accuracy: 0.6195 - val_loss: 2.5074 - val_accuracy: 0.1977 - val_top_k_categorical_accuracy: 0.6107
# Epoch 4/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.5051 - accuracy: 0.1970 - top_k_categorical_accuracy: 0.6183 - val_loss: 2.5066 - val_accuracy: 0.1968 - val_top_k_categorical_accuracy: 0.6147
# Epoch 5/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4952 - accuracy: 0.2015 - top_k_categorical_accuracy: 0.6301 - val_loss: 2.5042 - val_accuracy: 0.1895 - val_top_k_categorical_accuracy: 0.6028
# Epoch 6/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4876 - accuracy: 0.2063 - top_k_categorical_accuracy: 0.6268 - val_loss: 2.5040 - val_accuracy: 0.1949 - val_top_k_categorical_accuracy: 0.6090
# Epoch 7/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4857 - accuracy: 0.1978 - top_k_categorical_accuracy: 0.6284 - val_loss: 2.4994 - val_accuracy: 0.1963 - val_top_k_categorical_accuracy: 0.6136
# Epoch 8/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4801 - accuracy: 0.2015 - top_k_categorical_accuracy: 0.6313 - val_loss: 2.4965 - val_accuracy: 0.1887 - val_top_k_categorical_accuracy: 0.6085
# Epoch 9/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4761 - accuracy: 0.2064 - top_k_categorical_accuracy: 0.6326 - val_loss: 2.4983 - val_accuracy: 0.1947 - val_top_k_categorical_accuracy: 0.6109
# Epoch 10/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4734 - accuracy: 0.2049 - top_k_categorical_accuracy: 0.6372 - val_loss: 2.4980 - val_accuracy: 0.2026 - val_top_k_categorical_accuracy: 0.6123
# Epoch 11/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4683 - accuracy: 0.2078 - top_k_categorical_accuracy: 0.6378 - val_loss: 2.4999 - val_accuracy: 0.1952 - val_top_k_categorical_accuracy: 0.6088
# Epoch 12/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4647 - accuracy: 0.2092 - top_k_categorical_accuracy: 0.6411 - val_loss: 2.4995 - val_accuracy: 0.1879 - val_top_k_categorical_accuracy: 0.6117
# Epoch 13/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4663 - accuracy: 0.2082 - top_k_categorical_accuracy: 0.6396 - val_loss: 2.4970 - val_accuracy: 0.1944 - val_top_k_categorical_accuracy: 0.6047
# Epoch 14/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4640 - accuracy: 0.2076 - top_k_categorical_accuracy: 0.6398 - val_loss: 2.4947 - val_accuracy: 0.1993 - val_top_k_categorical_accuracy: 0.6082
# Epoch 15/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4617 - accuracy: 0.2082 - top_k_categorical_accuracy: 0.6388 - val_loss: 2.4969 - val_accuracy: 0.1917 - val_top_k_categorical_accuracy: 0.6066
# Epoch 16/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4583 - accuracy: 0.2084 - top_k_categorical_accuracy: 0.6418 - val_loss: 2.4989 - val_accuracy: 0.1936 - val_top_k_categorical_accuracy: 0.6036
# Epoch 17/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4596 - accuracy: 0.2115 - top_k_categorical_accuracy: 0.6372 - val_loss: 2.4974 - val_accuracy: 0.1890 - val_top_k_categorical_accuracy: 0.6079
# Epoch 18/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4570 - accuracy: 0.2103 - top_k_categorical_accuracy: 0.6414 - val_loss: 2.4980 - val_accuracy: 0.1911 - val_top_k_categorical_accuracy: 0.6128
# Epoch 19/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4536 - accuracy: 0.2136 - top_k_categorical_accuracy: 0.6427 - val_loss: 2.4983 - val_accuracy: 0.1925 - val_top_k_categorical_accuracy: 0.6085
# Epoch 20/20
# 129/129 [==============================] - 1s 6ms/step - loss: 2.4526 - accuracy: 0.2123 - top_k_categorical_accuracy: 0.6454 - val_loss: 2.4984 - val_accuracy: 0.1925 - val_top_k_categorical_accuracy: 0.6020

# %%
regression_GRU.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#history = regression_GRU.fit(x_train, y_train, batch_size=100, epochs=20, validation_data=(x_val, y_val))
GRU_history = regression_GRU.fit(x_train, y_train, batch_size=100, epochs=20, validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 129/129 [==============================] - 8s 19ms/step - loss: 2.6786 - accuracy: 0.1460 - val_loss: 2.5937 - val_accuracy: 0.1517
# Epoch 2/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.6148 - accuracy: 0.1595 - val_loss: 2.5775 - val_accuracy: 0.1474
# Epoch 3/20
# 129/129 [==============================] - 2s 15ms/step - loss: 2.5984 - accuracy: 0.1658 - val_loss: 2.5622 - val_accuracy: 0.1547
# Epoch 4/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5797 - accuracy: 0.1724 - val_loss: 2.5556 - val_accuracy: 0.1664
# Epoch 5/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5629 - accuracy: 0.1817 - val_loss: 2.5348 - val_accuracy: 0.1631
# Epoch 6/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5527 - accuracy: 0.1869 - val_loss: 2.5273 - val_accuracy: 0.1756
# Epoch 7/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5430 - accuracy: 0.1908 - val_loss: 2.5218 - val_accuracy: 0.1854
# Epoch 8/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5396 - accuracy: 0.1938 - val_loss: 2.5198 - val_accuracy: 0.1920
# Epoch 9/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5297 - accuracy: 0.1950 - val_loss: 2.5256 - val_accuracy: 0.1854
# Epoch 10/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5290 - accuracy: 0.1914 - val_loss: 2.5246 - val_accuracy: 0.1808
# Epoch 11/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5201 - accuracy: 0.1929 - val_loss: 2.5134 - val_accuracy: 0.1816
# Epoch 12/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5156 - accuracy: 0.1964 - val_loss: 2.5175 - val_accuracy: 0.1767
# Epoch 13/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5130 - accuracy: 0.1917 - val_loss: 2.5076 - val_accuracy: 0.1890
# Epoch 14/20
# 129/129 [==============================] - 2s 15ms/step - loss: 2.5069 - accuracy: 0.1901 - val_loss: 2.5024 - val_accuracy: 0.1968
# Epoch 15/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5045 - accuracy: 0.1985 - val_loss: 2.5023 - val_accuracy: 0.1944
# Epoch 16/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.5017 - accuracy: 0.1930 - val_loss: 2.5057 - val_accuracy: 0.1876
# Epoch 17/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.4940 - accuracy: 0.1997 - val_loss: 2.5005 - val_accuracy: 0.1884
# Epoch 18/20
# 129/129 [==============================] - 2s 15ms/step - loss: 2.4929 - accuracy: 0.1982 - val_loss: 2.5013 - val_accuracy: 0.1871
# Epoch 19/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.4908 - accuracy: 0.1955 - val_loss: 2.5021 - val_accuracy: 0.1824
# Epoch 20/20
# 129/129 [==============================] - 2s 14ms/step - loss: 2.4883 - accuracy: 0.1999 - val_loss: 2.5054 - val_accuracy: 0.1911

# %%
print("\n 정확도 : %.4f" % (regression_GRU.evaluate(x_test, y_test)[1]))
# Out:
# 58/58 [==============================] - 0s 3ms/step - loss: 2.5015 - accuracy: 0.1788
#
#  정확도 : 0.1788

# %%
regression_GRU.compile('adam', 'categorical_crossentropy', ['accuracy', 'top_k_categorical_accuracy'])

# %%
GRU_history = regression_GRU.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val))
# Out:
# Epoch 1/10
# 403/403 [==============================] - 10s 11ms/step - loss: 2.4911 - accuracy: 0.2009 - top_k_categorical_accuracy: 0.6273 - val_loss: 2.4990 - val_accuracy: 0.1813 - val_top_k_categorical_accuracy: 0.6147
# Epoch 2/10
# 403/403 [==============================] - 4s 9ms/step - loss: 2.4879 - accuracy: 0.1989 - top_k_categorical_accuracy: 0.6266 - val_loss: 2.4980 - val_accuracy: 0.1903 - val_top_k_categorical_accuracy: 0.6112
# Epoch 3/10
# 403/403 [==============================] - 4s 9ms/step - loss: 2.4868 - accuracy: 0.1991 - top_k_categorical_accuracy: 0.6298 - val_loss: 2.4988 - val_accuracy: 0.1900 - val_top_k_categorical_accuracy: 0.6169
# Epoch 4/10
# 403/403 [==============================] - 4s 9ms/step - loss: 2.4823 - accuracy: 0.1987 - top_k_categorical_accuracy: 0.6302 - val_loss: 2.4953 - val_accuracy: 0.1838 - val_top_k_categorical_accuracy: 0.6229
# Epoch 5/10
# 403/403 [==============================] - 4s 9ms/step - loss: 2.4828 - accuracy: 0.2024 - top_k_categorical_accuracy: 0.6247 - val_loss: 2.4979 - val_accuracy: 0.1909 - val_top_k_categorical_accuracy: 0.6071
# Epoch 6/10
# 403/403 [==============================] - 4s 9ms/step - loss: 2.4828 - accuracy: 0.2033 - top_k_categorical_accuracy: 0.6275 - val_loss: 2.4948 - val_accuracy: 0.1966 - val_top_k_categorical_accuracy: 0.6112
# Epoch 7/10
# 403/403 [==============================] - 4s 9ms/step - loss: 2.4794 - accuracy: 0.2009 - top_k_categorical_accuracy: 0.6305 - val_loss: 2.4996 - val_accuracy: 0.1822 - val_top_k_categorical_accuracy: 0.6047
# Epoch 8/10
# 403/403 [==============================] - 4s 9ms/step - loss: 2.4793 - accuracy: 0.2003 - top_k_categorical_accuracy: 0.6309 - val_loss: 2.4980 - val_accuracy: 0.1860 - val_top_k_categorical_accuracy: 0.6126
# Epoch 9/10
# 403/403 [==============================] - 4s 9ms/step - loss: 2.4768 - accuracy: 0.1985 - top_k_categorical_accuracy: 0.6305 - val_loss: 2.5005 - val_accuracy: 0.1865 - val_top_k_categorical_accuracy: 0.6058
# Epoch 10/10
# 403/403 [==============================] - 4s 9ms/step - loss: 2.4723 - accuracy: 0.2011 - top_k_categorical_accuracy: 0.6343 - val_loss: 2.5019 - val_accuracy: 0.1985 - val_top_k_categorical_accuracy: 0.6150

# %%
print("\n 정확도 : %.4f" % (regression_GRU.evaluate(x_test, y_test)[1]))
# Out:
# 58/58 [==============================] - 0s 3ms/step - loss: 2.4973 - accuracy: 0.1918 - top_k_categorical_accuracy: 0.6158
#
#  정확도 : 0.1918

# %%
y_pred = regression_GRU.predict(x_test)
# Out:
# 58/58 [==============================] - 1s 3ms/step

# %%
# Top-5 accuracy일 경우,

(sum(tf.keras.metrics.top_k_categorical_accuracy(y_test, y_pred, k=5))
/len(tf.keras.metrics.top_k_categorical_accuracy(y_test, y_pred, k=5)))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.61576086>

# %%
# Top-3 accuracy일 경우,

(sum(tf.keras.metrics.top_k_categorical_accuracy(y_test, y_pred, k=3))
/len(tf.keras.metrics.top_k_categorical_accuracy(y_test, y_pred, k=3)))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.4478261>
